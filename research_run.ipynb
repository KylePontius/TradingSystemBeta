# %%
from Research.Tools.ic import ICAnalysis
from Core.Config.specs.factor import FactorSpec

spec = FactorSpec(type="residual_momentum", params={"lookback": 63, "buffer" : 21})

ic = ICAnalysis(spec, holdingDays=[21, 63, 126, 252])
ic.compute()
ic.summary()
ic.plot()
